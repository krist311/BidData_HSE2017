# %%
import findspark
import pyspark
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
findspark.init('C:\spark\spark-2.2.0-bin-hadoop2.7')
session = pyspark.sql.SparkSession.builder.getOrCreate()

# %%
books=session.read.format("csv").option("header", "true").option("inferscheme", "true").option("sep", ";").load("BX-Books.csv")
users=session.read.format("csv").option("header", "true").option("inferscheme", "true").option("sep", ";").load("BX-Users.csv")
ratings=session.read.format("csv").option("header", "true").option("inferscheme", "true").option("sep", ";").load("BX-Book-Ratings.csv")

# %%
books.printSchema()
users.printSchema()
ratings.printSchema()
print(users)
# Out:
# root
#  |-- ISBN: string (nullable = true)
#  |-- Book-Title: string (nullable = true)
#  |-- Book-Author: string (nullable = true)
#  |-- Year-Of-Publication: string (nullable = true)
#  |-- Publisher: string (nullable = true)
#  |-- Image-URL-S: string (nullable = true)
#  |-- Image-URL-M: string (nullable = true)
#  |-- Image-URL-L: string (nullable = true)
#
# root
#  |-- User-ID: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Age: string (nullable = true)
#
# root
#  |-- User-ID: string (nullable = true)
#  |-- ISBN: string (nullable = true)
#  |-- Book-Rating: string (nullable = true)
#
# DataFrame[User-ID: string, Location: string, Age: string]

# %%
users = users.withColumn("Age", users.Age.cast("int"))
ratings = ratings.withColumn("Book-Rating", ratings["Book-Rating"].cast("int"))

# %%
users.printSchema()
# Out:
# root
#  |-- User-ID: string (nullable = true)
#  |-- Location: string (nullable = true)
#  |-- Age: integer (nullable = true)

# %%
p_ratings=ratings.groupBy("Book-Rating").count().toPandas()
p_ratings
# Out:
#     Book-Rating   count
# 0             1    1770
# 1             6   36924
# 2             3    5996
# 3             5   50974
# 4             9   67541
# 5             4    8904
# 6             8  103736
# 7             7   76457
# 8            10   78610
# 9             2    2759
# 10            0  716109

# %%
p_ratings = p_ratings.set_index(['Book-Rating']).sort_index()
plt.rc("font", size=15)
p_ratings.plot(kind='bar')
plt.title('Rating Distribution\n')
plt.xlabel('Rating')
plt.savefig('system1.png', bbox_inches='tight')
plt.show()

# %%
p_ages=users.groupBy("Age").count().sort("Age").toPandas() 
p_ages.columns=['Age','Total_Numbers']
p_ages=p_ages.dropna()

# %% [markdown]
# Строим график распределения возрастов пользователей, возраст большинства пользователей находится примерно промежутке от 25ти до 75ти лет

# %%
plt.plot(p_ages.Age,p_ages.Total_Numbers)
plt.title('Age Distribution\n')
plt.xlabel('Age')
plt.ylabel('count')
plt.savefig('system2.png', bbox_inches='tight')
plt.show()

# %%
top_ratings=ratings.groupBy('ISBN').count().sort('count', ascending=False).head(5)
top_ratings=session.createDataFrame(top_ratings)
top_ratings.show()
# Out:
# +----------+-----+
# |      ISBN|count|
# +----------+-----+
# |0971880107| 2502|
# |0316666343| 1295|
# |0385504209|  883|
# |0060928336|  732|
# |0312195516|  723|
# +----------+-----+

# %%
books.join(top_ratings,books.ISBN == top_ratings.ISBN, 'inner').toPandas()
# Out:
#          ISBN                                       Book-Title    Book-Author  \
# 0  0385504209                                The Da Vinci Code      Dan Brown
# 1  0312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
# 2  0316666343                        The Lovely Bones: A Novel   Alice Sebold
# 3  0060928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  0971880107                                      Wild Animus   Rich Shapero
#
#   Year-Of-Publication      Publisher  \
# 0                2003      Doubleday
# 1                1998    Picador USA
# 2                2002  Little, Brown
# 3                1997      Perennial
# 4                2004        Too Far
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0385504209.0...
# 1  http://images.amazon.com/images/P/0312195516.0...
# 2  http://images.amazon.com/images/P/0316666343.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# 4  http://images.amazon.com/images/P/0971880107.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0385504209.0...
# 1  http://images.amazon.com/images/P/0312195516.0...
# 2  http://images.amazon.com/images/P/0316666343.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# 4  http://images.amazon.com/images/P/0971880107.0...
#
#                                          Image-URL-L        ISBN  count
# 0  http://images.amazon.com/images/P/0385504209.0...  0385504209    883
# 1  http://images.amazon.com/images/P/0312195516.0...  0312195516    723
# 2  http://images.amazon.com/images/P/0316666343.0...  0316666343   1295
# 3  http://images.amazon.com/images/P/0060928336.0...  0060928336    732
# 4  http://images.amazon.com/images/P/0971880107.0...  0971880107   2502

# %%
from pyspark.sql import functions as F
top_ratings_by_avarage = ratings.groupBy("ISBN").agg(
    F.avg("Book-Rating").alias("bookRating"), 
).sort('bookRating', ascending=False).head(5)
top_ratings_by_avarage=session.createDataFrame(top_ratings_by_avarage)
top_ratings_by_avarage.show()
# Out:
# +----------+----------+
# |      ISBN|bookRating|
# +----------+----------+
# |0960394621|      10.0|
# |0786210966|      10.0|
# |0816421269|      10.0|
# |1585007366|      10.0|
# |0974506818|      10.0|
# +----------+----------+

# %%
books.join(top_ratings_by_avarage,books.ISBN == top_ratings_by_avarage.ISBN, 'inner').toPandas()
# Out:
#          ISBN                                         Book-Title  \
# 0  0786210966  Deal on Ice (Thorndike Large Print Americana S...
# 1  0816421269       Watch and Pray With Me: The Seven Last Words
# 2  0960394621  Creme De Colorado Cookbook (Celebrating Twenty...
# 3  0974506818   Smile for the Speed Camera: Photo Radar Exposed!
# 4  1585007366                          Sang Froyd (Balona Books)
#
#                Book-Author Year-Of-Publication  \
# 0           Les Standiford                1997
# 1              Karl Rahner                1977
# 2  Junior League of Denver                1987
# 3             Susan Kayler                2004
# 4          Jonathan Pearce                1999
#
#                         Publisher  \
# 0                    Thorndike Pr
# 1            Simon &amp; Schuster
# 2         Junior League of Denver
# 3  Roadrunner Publishing Partners
# 4                1stBooks Library
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0786210966.0...
# 1  http://images.amazon.com/images/P/0816421269.0...
# 2  http://images.amazon.com/images/P/0960394621.0...
# 3  http://images.amazon.com/images/P/0974506818.0...
# 4  http://images.amazon.com/images/P/1585007366.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0786210966.0...
# 1  http://images.amazon.com/images/P/0816421269.0...
# 2  http://images.amazon.com/images/P/0960394621.0...
# 3  http://images.amazon.com/images/P/0974506818.0...
# 4  http://images.amazon.com/images/P/1585007366.0...
#
#                                          Image-URL-L        ISBN  bookRating
# 0  http://images.amazon.com/images/P/0786210966.0...  0786210966        10.0
# 1  http://images.amazon.com/images/P/0816421269.0...  0816421269        10.0
# 2  http://images.amazon.com/images/P/0960394621.0...  0960394621        10.0
# 3  http://images.amazon.com/images/P/0974506818.0...  0974506818        10.0
# 4  http://images.amazon.com/images/P/1585007366.0...  1585007366        10.0

# %%
user_rating_counts = ratings.groupBy("User-ID").count()
good_users = user_rating_counts.filter(user_rating_counts["count"]>=200)
filtered_ratings = good_users.join(ratings, on='User-ID', how='left_outer')

books_count = ratings.groupBy("ISBN").count()
books_select = books_count.filter(books_count['count'] >= 100)
filtered_ratings = books_select.join(filtered_ratings, on='ISBN', how='left_outer')
ratings_drop = filtered_ratings.drop('count')
ratings_drop.head(5)
# Out:
# [Row(ISBN='0515135739', User-ID='262399', Book-Rating=0),
#  Row(ISBN='0515135739', User-ID='28591', Book-Rating=0),
#  Row(ISBN='0515135739', User-ID='108285', Book-Rating=0),
#  Row(ISBN='0515135739', User-ID='153662', Book-Rating=0),
#  Row(ISBN='0515135739', User-ID='87746', Book-Rating=0)]

# %%
r_drop_count = ratings_drop.groupBy("ISBN").agg(
    F.avg("Book-Rating").alias("bookRating"), 
).sort('bookRating', ascending=False)

# %%
r_drop_count.show(5)
# Out:
# +----------+-----------------+
# |      ISBN|       bookRating|
# +----------+-----------------+
# |0590353403|5.644444444444445|
# |0439064864|5.596774193548387|
# |0439136350|5.426470588235294|
# |0439139597|5.343283582089552|
# |039592720X|4.478260869565218|
# +----------+-----------------+
# only showing top 5 rows

# %%
ratings_pivot = ratings_drop.groupby('User-ID').pivot('ISBN').max('Book-Rating')

# %%
from pyspark.mllib.stat import Statistics
from pyspark.mllib.linalg import Vectors
rdd = ratings_pivot.rdd.map(lambda data: Vectors.dense([float(c) for c in data]))
particular_book_rdd = ratings_pivot.select('0316666343').rdd.map(lambda data: Vectors.dense([float(c) for c in data]))

# %%
ratings_pivot.limit(20).toPandas()
# Out:
#    User-ID  002542730X  0060008032  0060096195 006016848X 0060173289  \
# 0   230249         0.0         NaN         NaN       None       None
# 1    32773         NaN         NaN         NaN       None       None
# 2   227447         NaN         0.0         NaN       None       None
# 3   104665         NaN         NaN         NaN       None       None
# 4   148744         NaN         NaN         NaN       None       None
# 5    92547         NaN         NaN         NaN       None       None
# 6   241548         NaN         NaN         NaN       None       None
# 7   131046         NaN         0.0         NaN       None       None
# 8   274061         NaN         NaN         NaN       None       None
# 9   126604         0.0         NaN         NaN       None       None
# 10  212965         NaN         NaN         NaN       None       None
# 11   73394         NaN         NaN         0.0       None       None
# 12  162639         NaN         NaN         0.0       None       None
# 13  207499         NaN         NaN         NaN       None       None
# 14  109461         NaN         NaN         NaN       None       None
# 15   83287         NaN         NaN         NaN       None       None
# 16   31391         NaN         NaN         NaN       None       None
# 17   88793         NaN         0.0         NaN       None       None
# 18   37712         NaN         NaN         NaN       None       None
# 19  226965         NaN         NaN         NaN       None       None
#
#    0060175400  006019491X  0060199652  0060391626     ...      1558744630  \
# 0        None         NaN         0.0         NaN     ...             NaN
# 1        None         NaN         NaN         NaN     ...             NaN
# 2        None         NaN         NaN         NaN     ...             NaN
# 3        None         NaN         NaN         NaN     ...             NaN
# 4        None         NaN         NaN         NaN     ...             0.0
# 5        None         NaN         NaN         NaN     ...             NaN
# 6        None         NaN         NaN         NaN     ...             NaN
# 7        None         NaN         NaN         NaN     ...             NaN
# 8        None         NaN         NaN         NaN     ...             NaN
# 9        None         NaN         NaN         6.0     ...             NaN
# 10       None         NaN         NaN         NaN     ...             NaN
# 11       None         NaN         NaN         NaN     ...             NaN
# 12       None         NaN         NaN         NaN     ...             NaN
# 13       None         NaN         NaN         NaN     ...             NaN
# 14       None         NaN         NaN         NaN     ...             NaN
# 15       None         NaN         NaN         NaN     ...             NaN
# 16       None         NaN         NaN         NaN     ...             NaN
# 17       None         NaN         NaN         NaN     ...             NaN
# 18       None         9.0         NaN         NaN     ...             NaN
# 19       None         NaN         NaN         6.0     ...             NaN
#
#     1558745157  1559029838  1573225517  1573225789  1573227331  1573229326  \
# 0          NaN         NaN         NaN         NaN        None         NaN
# 1          NaN         0.0         NaN         NaN        None         NaN
# 2          NaN         0.0         0.0         NaN        None         NaN
# 3          NaN         NaN         NaN         NaN        None         NaN
# 4          NaN         NaN         NaN         8.0        None         0.0
# 5          NaN         0.0         NaN         NaN        None         NaN
# 6          NaN         NaN         NaN         7.0        None         NaN
# 7          NaN         NaN         NaN         NaN        None         NaN
# 8          NaN         NaN         NaN         NaN        None         NaN
# 9          NaN         NaN         NaN         NaN        None         NaN
# 10         NaN         NaN         NaN         NaN        None         NaN
# 11         NaN         NaN         NaN         NaN        None         NaN
# 12         NaN         NaN         NaN         NaN        None         0.0
# 13         NaN         NaN         NaN         NaN        None         NaN
# 14         NaN         NaN         NaN         NaN        None         NaN
# 15         0.0        10.0         NaN         NaN        None         NaN
# 16         NaN         NaN         NaN         NaN        None         NaN
# 17         NaN         NaN         NaN         NaN        None         NaN
# 18         NaN         NaN         NaN         NaN        None         0.0
# 19         NaN         NaN         NaN         NaN        None         NaN
#
#     1573229571  1592400876  1878424319
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          0.0         NaN         0.0
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         9.0         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         8.0         NaN         NaN
# 19         NaN         NaN         NaN
#
# [20 rows x 732 columns]

# %%
from pyspark.ml.stat import Correlation


bones_book = '0316666343'
corr_values = {}
for book in ratings_pivot.columns[1:]:
    corr_values[book] = ratings_pivot.stat.corr(bones_book, book)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-9e27720641ed> in <module>()
#       5 corr_values = {}
#       6 for book in ratings_pivot.columns[1:]:
# ----> 7     corr_values[book] = ratings_pivot.stat.corr(bones_book, book)
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\sql\dataframe.py in corr(self, col1, col2, method)
#    1770
#    1771     def corr(self, col1, col2, method=None):
# -> 1772         return self.df.corr(col1, col2, method)
#    1773
#    1774     corr.__doc__ = DataFrame.corr.__doc__
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\site-packages\pyspark\sql\dataframe.py in corr(self, col1, col2, method)
#    1541             raise ValueError("Currently only the calculation of the Pearson Correlation " +
#    1542                              "coefficient is supported.")
# -> 1543         return self._jdf.stat().corr(col1, col2, method)
#    1544
#    1545     @since(1.4)
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1129             proto.END_COMMAND_PART
#    1130
# -> 1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
#    1133             answer, self.gateway_client, self.target_id, self.name)
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\site-packages\py4j\java_gateway.py in send_command(self, command, retry, binary)
#     881         connection = self._get_connection()
#     882         try:
# --> 883             response = connection.send_command(command)
#     884             if binary:
#     885                 return response, self._create_connection_guard(connection)
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\site-packages\py4j\java_gateway.py in send_command(self, command)
#    1026
#    1027         try:
# -> 1028             answer = smart_decode(self.stream.readline()[:-1])
#    1029             logger.debug("Answer received: {0}".format(answer))
#    1030             if answer.startswith(proto.RETURN_MESSAGE):
#
# C:\Users\dako0915\AppData\Local\Continuum\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
